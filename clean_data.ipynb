# %%
import pandas as pd

# %%
# set categorical types
category_cols = ['Rating','Type','Status','Source']
int_cols = ['Rank','Episodes','Scored By','Popularity','Favorites','Members']
float_cols = ['Score']

types = dict([(i,'category') for i in category_cols])

df = pd.read_csv('anime-dataset-2023.csv')
df = df.astype(types)
df.dtypes
# Out:
# anime_id           int64
# Name              object
# English name      object
# Other name        object
# Score             object
# Genres            object
# Synopsis          object
# Type            category
# Episodes          object
# Aired             object
# Premiered         object
# Status          category
# Producers         object
# Licensors         object
# Studios           object
# Source          category
# Duration          object
# Rating          category
# Rank              object
# Popularity         int64
# Favorites          int64
# Scored By         object
# Members            int64
# Image URL         object
# dtype: object

# %%
for cat in category_cols:
    print(cat)
    print(df[cat].cat.categories)
# Out:
# Rating
# Index(['G - All Ages', 'PG - Children', 'PG-13 - Teens 13 or older',
#        'R - 17+ (violence & profanity)', 'R+ - Mild Nudity', 'Rx - Hentai',
#        'UNKNOWN'],
#       dtype='object')
# Type
# Index(['Movie', 'Music', 'ONA', 'OVA', 'Special', 'TV', 'UNKNOWN'], dtype='object')
# Status
# Index(['Currently Airing', 'Finished Airing', 'Not yet aired'], dtype='object')
# Source
# Index(['4-koma manga', 'Book', 'Card game', 'Game', 'Light novel', 'Manga',
#        'Mixed media', 'Music', 'Novel', 'Original', 'Other', 'Picture book',
#        'Radio', 'Unknown', 'Visual novel', 'Web manga', 'Web novel'],
#       dtype='object')

# %% [markdown]
# ## Clean Numeric Columns

# %%
for col in int_cols:
    df[col] = pd.to_numeric(df[col],errors='coerce').fillna(-1).astype('int64')
for col in float_cols:
    df[col] = pd.to_numeric(df[col],errors='coerce').fillna(-1).astype('float64')
print(len(df.index))
df.dtypes
# Out:
# 24905
# anime_id           int64
# Name              object
# English name      object
# Other name        object
# Score            float64
# Genres            object
# Synopsis          object
# Type            category
# Episodes           int64
# Aired             object
# Premiered         object
# Status          category
# Producers         object
# Licensors         object
# Studios           object
# Source          category
# Duration          object
# Rating          category
# Rank               int64
# Popularity         int64
# Favorites          int64
# Scored By          int64
# Members            int64
# Image URL         object
# dtype: object

# %%
# we drop the rows that have no score
for i in int_cols:
    df = df[df[i]>0]
for i in float_cols:
    df = df[df[i]>0]
print(len(df.index))

df.head()
# Out:
# 10619
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name  Score  \
# 0                         カウボーイビバップ   8.75
# 1                    カウボーイビバップ 天国の扉   8.38
# 2                             トライガン   8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)   7.25
# 4                            冒険王ビィト   6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type  Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV        26
# 1  Another day, another bounty—such is the life o...  Movie         1
# 2  Vash the Stampede is the man with a $$60,000,0...     TV        26
# 3  Robin Sena is a powerful craft user drafted in...     TV        26
# 4  It is the dark century and the people are suff...     TV        52
#
#                           Aired  ...         Studios    Source       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...         Sunrise  Original  24 min per ep
# 1                   Sep 1, 2001  ...           Bones  Original    1 hr 55 min
# 2   Apr 1, 1998 to Sep 30, 1998  ...        Madhouse     Manga  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...         Sunrise  Original  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation     Manga  23 min per ep
#
#                            Rating  Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41         43     78525    914193
# 1  R - 17+ (violence & profanity)   189        602      1448    206248
# 2       PG-13 - Teens 13 or older   328        246     15035    356739
# 3       PG-13 - Teens 13 or older  2764       1795       613     42829
# 4                   PG - Children  4240       5126        14      6413
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Clean Premiered column

# %%
df['Premiered'] = df['Premiered'].astype('string')
df[['season','year']] = df['Premiered'].str.split(' ',n=1,expand=True)

# create categorical data based on the order of seasons
dtype = pd.CategoricalDtype(['winter', 'spring', 'summer', 'fall', 'UNKNOWN'], ordered=True)
df['season'] = df['season'].astype(dtype)

# replace categories with their codes
df['season'] = df['season'].cat.codes

# remove UNKNOWNs
df = df[df['season'] < 4]
print(len(df.index))

# create new row
df['year'] = df['year'].astype(int)
df['Premier_Month'] = (df['year']-1900)*12 + df['season']*3
# Out:
# 4281

# %%
df = df.drop(columns=['Premiered','year'])
df.head()
# Out:
#    anime_id                Name            English name  \
# 0         1        Cowboy Bebop            Cowboy Bebop
# 2         6              Trigun                  Trigun
# 3         7  Witch Hunter Robin      Witch Hunter Robin
# 4         8      Bouken Ou Beet  Beet the Vandel Buster
# 5        15        Eyeshield 21                 UNKNOWN
#
#                          Other name  Score  \
# 0                         カウボーイビバップ   8.75
# 2                             トライガン   8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)   7.25
# 4                            冒険王ビィト   6.94
# 5                          アイシールド21   7.92
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
# 5                                Sports
#
#                                             Synopsis Type  Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...   TV        26
# 2  Vash the Stampede is the man with a $$60,000,0...   TV        26
# 3  Robin Sena is a powerful craft user drafted in...   TV        26
# 4  It is the dark century and the people are suff...   TV        52
# 5  Shy, reserved, and small-statured, Deimon High...   TV       145
#
#                           Aired  ...       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...  24 min per ep
# 2   Apr 1, 1998 to Sep 30, 1998  ...  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  23 min per ep
# 5   Apr 6, 2005 to Mar 19, 2008  ...  23 min per ep
#
#                            Rating  Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41         43     78525    914193
# 2       PG-13 - Teens 13 or older   328        246     15035    356739
# 3       PG-13 - Teens 13 or older  2764       1795       613     42829
# 4                   PG - Children  4240       5126        14      6413
# 5       PG-13 - Teens 13 or older   688       1252      1997     86524
#
#    Members                                          Image URL  season  \
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...       1
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...       1
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...       2
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...       3
# 5   177688  https://cdn.myanimelist.net/images/anime/1079/...       1
#
#    Premier_Month
# 0           1179
# 2           1179
# 3           1230
# 4           1257
# 5           1263
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Clean Genre Row

# %%
genres = ['Action', 'Adventure', 'Avant Garde', 'Award Winning', 'Boys Love', 'Comedy', 'Drama', 'Fantasy', 'Girls Love', 'Gourmet', 'Horror', 'Mystery', 'Romance', 'Sci-Fi', 'Slice of Life', 'Sports', 'Supernatural', 'Suspense', 'Ecchi']

df['Genres'] = df['Genres'].astype('string')
for genre in genres:
    df[genre] = df['Genres'].str.contains(genre)
df.head()
# Out:
#    anime_id                Name            English name  \
# 0         1        Cowboy Bebop            Cowboy Bebop
# 2         6              Trigun                  Trigun
# 3         7  Witch Hunter Robin      Witch Hunter Robin
# 4         8      Bouken Ou Beet  Beet the Vandel Buster
# 5        15        Eyeshield 21                 UNKNOWN
#
#                          Other name  Score  \
# 0                         カウボーイビバップ   8.75
# 2                             トライガン   8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)   7.25
# 4                            冒険王ビィト   6.94
# 5                          アイシールド21   7.92
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
# 5                                Sports
#
#                                             Synopsis Type  Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...   TV        26
# 2  Vash the Stampede is the man with a $$60,000,0...   TV        26
# 3  Robin Sena is a powerful craft user drafted in...   TV        26
# 4  It is the dark century and the people are suff...   TV        52
# 5  Shy, reserved, and small-statured, Deimon High...   TV       145
#
#                           Aired  ... Gourmet Horror Mystery Romance Sci-Fi  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...   False  False   False   False   True
# 2   Apr 1, 1998 to Sep 30, 1998  ...   False  False   False   False   True
# 3   Jul 3, 2002 to Dec 25, 2002  ...   False  False    True   False  False
# 4  Sep 30, 2004 to Sep 29, 2005  ...   False  False   False   False  False
# 5   Apr 6, 2005 to Mar 19, 2008  ...   False  False   False   False  False
#
#   Slice of Life Sports  Supernatural  Suspense  Ecchi
# 0         False  False         False     False  False
# 2         False  False         False     False  False
# 3         False  False          True     False  False
# 4         False  False          True     False  False
# 5         False   True         False     False  False
#
# [5 rows x 44 columns]

# %%
def extract_aired_year(aired_string):
  """
  Extracts the starting year from an aired timeline string.

  Args:
      aired_string (str): The aired timeline string in the format "Start date to End date".

  Returns:
      int: The extracted starting year as an integer (or None if not found).
  """
  if pd.isna(aired_string):
    return None
  try:
    # Split the string and extract the first year (assuming starting year)
    year_str = aired_string.split("to")[0].split()[-1]
    return int(year_str)
  except (ValueError, IndexError):
    # Handle potential errors in parsing the date format
    return None

# Apply the function to the 'Aired' column and create a new 'AiredYear' column
df['AiredYear'] = df['Aired'].apply(extract_aired_year)

# Cast the 'AiredYear' column to int64 datatype (if not already)
df['AiredYear'] = pd.to_numeric(df['AiredYear'], errors='coerce')  # Handle non-numeric values

df
# Out:
#        anime_id                                         Name  \
# 0             1                                 Cowboy Bebop
# 2             6                                       Trigun
# 3             7                           Witch Hunter Robin
# 4             8                               Bouken Ou Beet
# 5            15                                 Eyeshield 21
# ...         ...                                          ...
# 23479     53621  Jijou wo Shiranai Tenkousei ga Guigui Kuru.
# 23533     53698                               World Dai Star
# 23658     53874               Pokemon: Mezase Pokemon Master
# 23928     54259                        Rokudou no Onna-tachi
# 24197     54738    Majutsushi Orphen Hagure Tabi: Seiiki-hen
#
#                                             English name  \
# 0                                           Cowboy Bebop
# 2                                                 Trigun
# 3                                     Witch Hunter Robin
# 4                                 Beet the Vandel Buster
# 5                                                UNKNOWN
# ...                                                  ...
# 23479                           My Clueless First Friend
# 23533              Stella of the Theater: World Dai Star
# 23658                                            UNKNOWN
# 23928                                 Rokudo's Bad Girls
# 24197  Sorcerous Stabber Orphen -Doom of Dragon's San...
#
#                              Other name  Score  \
# 0                             カウボーイビバップ   8.75
# 2                                 トライガン   8.22
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)   7.25
# 4                                冒険王ビィト   6.94
# 5                              アイシールド21   7.92
# ...                                 ...    ...
# 23479                事情を知らない転校生がグイグイくる。   7.47
# 23533                         ワールドダイスター   6.72
# 23658             ポケットモンスター めざせポケモンマスター   7.56
# 23928                      六道の悪女〈おんな〉たち   6.19
# 24197                  魔術士オーフェンはぐれ旅 聖域編   6.09
#
#                                      Genres  \
# 0             Action, Award Winning, Sci-Fi
# 2                 Action, Adventure, Sci-Fi
# 3      Action, Drama, Mystery, Supernatural
# 4          Adventure, Fantasy, Supernatural
# 5                                    Sports
# ...                                     ...
# 23479                                Comedy
# 23533                               UNKNOWN
# 23658    Action, Adventure, Comedy, Fantasy
# 23928                       Comedy, Romance
# 24197     Action, Adventure, Drama, Fantasy
#
#                                                 Synopsis Type  Episodes  \
# 0      Crime is timeless. By the year 2071, humanity ...   TV        26
# 2      Vash the Stampede is the man with a $$60,000,0...   TV        26
# 3      Robin Sena is a powerful craft user drafted in...   TV        26
# 4      It is the dark century and the people are suff...   TV        52
# 5      Shy, reserved, and small-statured, Deimon High...   TV       145
# ...                                                  ...  ...       ...
# 23479  Akane Nishimura's quiet nature makes her class...   TV        13
# 23533  After Dai Star stage performers exploded in wo...   TV        12
# 23658  By embracing challenges, learning from failure...   TV        11
# 23928  Tousuke Rokudou is a first-year attending Aomo...   TV        12
# 24197  With no other choice left, Orphen is led by Wi...   TV        12
#
#                               Aired  ... Horror Mystery Romance Sci-Fi  \
# 0       Apr 3, 1998 to Apr 24, 1999  ...  False   False   False   True
# 2       Apr 1, 1998 to Sep 30, 1998  ...  False   False   False   True
# 3       Jul 3, 2002 to Dec 25, 2002  ...  False    True   False  False
# 4      Sep 30, 2004 to Sep 29, 2005  ...  False   False   False  False
# 5       Apr 6, 2005 to Mar 19, 2008  ...  False   False   False  False
# ...                             ...  ...    ...     ...     ...    ...
# 23479    Apr 9, 2023 to Jul 2, 2023  ...  False   False   False  False
# 23533   Apr 9, 2023 to Jun 25, 2023  ...  False   False   False  False
# 23658  Jan 13, 2023 to Mar 24, 2023  ...  False   False   False  False
# 23928   Apr 8, 2023 to Jun 24, 2023  ...  False   False    True  False
# 24197  Apr 12, 2023 to Jun 28, 2023  ...  False   False   False  False
#
#       Slice of Life Sports Supernatural  Suspense  Ecchi  AiredYear
# 0             False  False        False     False  False       1998
# 2             False  False        False     False  False       1998
# 3             False  False         True     False  False       2002
# 4             False  False         True     False  False       2004
# 5             False   True        False     False  False       2005
# ...             ...    ...          ...       ...    ...        ...
# 23479         False  False        False     False  False       2023
# 23533         False  False        False     False  False       2023
# 23658         False  False        False     False  False       2023
# 23928         False  False        False     False  False       2023
# 24197         False  False        False     False  False       2023
#
# [4281 rows x 45 columns]

# %%
df['Duration_mins']=df['Duration'].str.slice(start=0, stop=2)
df['Duration_mins'] = df['Duration_mins'].astype('int64')

df.head()
# Out:
#    anime_id                Name            English name  \
# 0         1        Cowboy Bebop            Cowboy Bebop
# 2         6              Trigun                  Trigun
# 3         7  Witch Hunter Robin      Witch Hunter Robin
# 4         8      Bouken Ou Beet  Beet the Vandel Buster
# 5        15        Eyeshield 21                 UNKNOWN
#
#                          Other name  Score  \
# 0                         カウボーイビバップ   8.75
# 2                             トライガン   8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)   7.25
# 4                            冒険王ビィト   6.94
# 5                          アイシールド21   7.92
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
# 5                                Sports
#
#                                             Synopsis Type  Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...   TV        26
# 2  Vash the Stampede is the man with a $$60,000,0...   TV        26
# 3  Robin Sena is a powerful craft user drafted in...   TV        26
# 4  It is the dark century and the people are suff...   TV        52
# 5  Shy, reserved, and small-statured, Deimon High...   TV       145
#
#                           Aired  ... Mystery Romance Sci-Fi Slice of Life  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...   False   False   True         False
# 2   Apr 1, 1998 to Sep 30, 1998  ...   False   False   True         False
# 3   Jul 3, 2002 to Dec 25, 2002  ...    True   False  False         False
# 4  Sep 30, 2004 to Sep 29, 2005  ...   False   False  False         False
# 5   Apr 6, 2005 to Mar 19, 2008  ...   False   False  False         False
#
#   Sports Supernatural Suspense  Ecchi  AiredYear  Duration_mins
# 0  False        False    False  False       1998             24
# 2  False        False    False  False       1998             24
# 3  False         True    False  False       2002             25
# 4  False         True    False  False       2004             23
# 5   True        False    False  False       2005             23
#
# [5 rows x 46 columns]

# %%
df.to_csv('cleaned_data.csv')
